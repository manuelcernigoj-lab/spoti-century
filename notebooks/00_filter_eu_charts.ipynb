# %%
import pandas as pd

# %%
charts_df = pd.read_csv("../data/kaggle1/charts.csv")
eu_countries = pd.read_csv("../data/european_countries.csv")['country']

# %%
eu_charts_df = charts_df[charts_df['region'].isin(eu_countries)]
eu_charts_df.to_csv("../data/eu_charts.csv", index=False)
